# %% [markdown]
# # Resumo do código
#
# ### <u>Código que gera o ficheiro Long_DataFusion</u>
# ---
# O objectivo é receber dados dos Ninjas e da Delta e devolver um conjunto de métricas para estudar o comportamento de vários produtos em diversas lojas.
#
# ---
# - Inputs
#
# > __Dados dos ninjas__ em formato Wide
# > - 1's e 0's consoante a presença e ausência do produto, Data e Loja
#
# > __Dados da Delta__ em formato Wide
# > - Stocks e trânsito, Sellout dia anterior
#
# - Outputs
#
# > __Ficheiro Long__ (artigos na mesma coluna)
#
# > __Métricas novas:__
# > - Roturas de Stock, Roturas de Linear, Roturas consecutivas por dia, Roturas consecutivas por fim de semana
# > - Sinal
# > - Ciclos e Adequação de Stock
# > - Restock

# %%
import pandas as pd
import numpy as np
import json

def escrever_excel(dataFrame, nomeFicheiro):
    dataFrame.to_excel('D:\\B&N Dados\\Delta\\Piloto\\%s.xlsx' %nomeFicheiro, index=False)
    
def ler_json(ficheiro):
    with open('D:\\B&N Dados\\Delta\\%s.json' %ficheiro, 'r') as file:
        mapa = json.load(file)
    return mapa

# %% [raw]
# mapa_produtos = ler_json("dicionário_produtos")
# mapa_produtos = {int(key): value for key, value in mapa_produtos.items()}

# %% [markdown]
# # Ler e Mudar nomes

# %% [markdown]
# - # `dfNinjas`

# %%
#Info Ninja
dfNinjas1=pd.read_excel("D:\\B&N Dados\\Delta\\Piloto\\1Ninjas1fds.xlsx")
dfNinjas2=pd.read_excel("D:\\B&N Dados\\Delta\\Piloto\\1Ninjas2fds.xlsx")
dfNinjas3=pd.read_excel("D:\\B&N Dados\\Delta\\Piloto\\1Ninjas3fds.xlsx")
dfNinjas4=pd.read_excel("D:\\B&N Dados\\Delta\\Piloto\\1Ninjas4fds.xlsx")

dataframes=[dfNinjas1,dfNinjas2,dfNinjas3,dfNinjas4]
dfNinjas=pd.concat(dataframes, ignore_index=True)
dfNinjas = dfNinjas.rename(columns={' Data de Resposta': 'DATA', "Código da loja":"STORE"})

# %%
mapa_lojas = dfNinjas.set_index(dfNinjas.columns[1])[dfNinjas.columns[0]].to_dict()

# %% [markdown]
# > Definir variáveis importantes
# > - Se houver um ficheiro com os produtos

# %%
# Ler ficheiro para dataframe
df_produtos = pd.read_csv('D:\\B&N Dados\\Delta\\Piloto\\produtos.txt', header=None)

# Passar para uma lista
produtos = df_produtos[0].tolist()
resto = dfNinjas.columns.difference(produtos)

# %% [markdown]
# > - Se se quiser usar o primeiro e o último produtos

# %% [raw]
# # Nomes de entrada
# x= input("Primeiro produto: ")                # CAFÉ DELTA Q MYTHIQ 80CAP
# y= input("Último produto: ")                  # Delta Cafés Mistura + café 200grs
#
# # Passar para uma lista
# produtos = dfNinjas.columns[dfNinjas.columns.get_loc(x): dfNinjas.columns.get_loc(y)+1].tolist()
# resto = dfNinjas.columns.difference(produtos)

# %% [markdown]
# # Formato Long

# %%
dfNinjasLong = dfNinjas.melt(id_vars=resto, value_vars=produtos, var_name='DESC_ARTIGO', value_name='NinjaInfo')

# %% [markdown]
# - Altura do dia

# %%
# Hora para datetime
dfNinjasLong['Hora']= pd.to_datetime(dfNinjasLong['Hora'], format='%H:%M:%S', errors='coerce').dt.time  

#coluna nova para data e hora
dfNinjasLong['DataComp'] = pd.to_datetime(dfNinjasLong['DATA'].dt.strftime('%Y-%m-%d') + ' ' + dfNinjasLong['Hora'].astype(str), errors='coerce') 

altura_do_dia = lambda x: 'Manhã' if x < 13 else ('Tarde' if x < 18 else ('Noite' if x < 24 else 'Indefinido'))

dfNinjasLong['Altura_do_Dia'] = dfNinjasLong['DataComp'].apply(lambda x: altura_do_dia(x.hour))
dfNinjasLong=dfNinjasLong.drop(columns=["DataComp"])

# %% [markdown]
# - # `dfDelta`

# %% [raw]
# # Ler o ficheiro long com Stocks e Fornecimento
# dfDelta=pd.read_excel("D:\\B&N Dados\\Delta\\Piloto\\2_Delta_e2fdsantes.xlsx", sheet_name="Sheet1")
#
# # Renomear
# dfDelta = dfDelta.rename(columns={"STORE_NAME":"Loja"})

# %%
# Ler o ficheiro long com Stocks e Fornecimento
dfDelta=pd.read_csv("D:\\B&N Dados\\Delta\\Stocks\\StocksTotal\\Mil_Métricas_Piloto.csv")

# Renomear
dfDelta = dfDelta.rename(columns={"STORE_NAME":"Loja"})

# %%
dfDelta['DATA'] = pd.to_datetime(dfDelta['DATA'], format='%Y-%m-%d')

# %% [markdown]
# - Tirar tudo o que termina com "Dias_Antes"

# %%
dfDelta = dfDelta.filter(regex='^(?!.*_Dias_Antes$)')

# %% [markdown]
# > Reposição

# %%
# Ler o ficheiro com os nomes das lojas que fazem reposição
dfRepos=pd.read_excel("D:\\B&N Dados\\Delta\\Reposição_Sonae_Código.xlsx")

# Criar coluna que determina quais lojas têm reposição
dfDelta['Reposição'] = [1 if val in dfRepos['STORE'].values else 0 for val in dfDelta['STORE']]

# %% [markdown]
# # <font color="green">Estruturar a base de dados</font>

# %% [markdown]
# - Fazer o dataframe que servirá de modelo

# %%
import itertools

# Definir variáveis para cada coluna
dates = dfNinjasLong["DATA"].unique()
stores = dfNinjasLong["STORE"].unique()
desc_artigos = dfNinjasLong["DESC_ARTIGO"].unique()

# Criar todas as combinações possíveis
combinations = list(itertools.product(dates, stores, desc_artigos))

# Criar o DataDrame com as combinações possíveis
dfModelo = pd.DataFrame(combinations, columns=['DATA', 'STORE', 'DESC_ARTIGO'])

# Converter a coluna da "DATA" para datetime
dfModelo['DATA'] = pd.to_datetime(dfModelo['DATA'], format='%Y-%m-%d')

# %%
# Definir os valores que queremos para as alturas do dia
times = ['Manhã', 'Tarde', 'Noite']

# Criar uma lista de dfs, vai ter o número de alturas do dia certo
dfs = [dfModelo.assign(Altura_do_Dia=t) for t in times]

# Juntar tudo no mesmo dataframe
df_Mergir = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# > `MERGIR`

# %%
dfNinjasLong = pd.merge(df_Mergir, dfNinjasLong, on=['DATA', 'STORE', 'DESC_ARTIGO', 'Altura_do_Dia'], how='left')

dfNinjasLong = dfNinjasLong.sort_values(by=["STORE","DESC_ARTIGO","DATA"])

# %% [markdown]
# - Semana

# %%
dfNinjasLong['Semana'] = dfNinjasLong['DATA'].dt.isocalendar().week

dfNinjasLong['Semana'] = dfNinjasLong.groupby('Semana').ngroup() + 1

# %% [markdown]
# - Dia

# %%
nome_dia = dfNinjasLong['DATA'].dt.day_name().map({'Friday': 'Sexta', 'Saturday': 'Sábado', 'Sunday': 'Domingo'})

dfNinjasLong['Dia'] = nome_dia

# %% [markdown]
# ## <font color=green> Fim base </font>
#
# ---

# %%
dfNinjasLong['Nome da Loja'] = dfNinjasLong['Nome da Loja'].fillna(dfNinjasLong['STORE'].map(mapa_lojas))
dfNinjasLong.head()
# Out:
#            DATA  STORE                             DESC_ARTIGO Altura_do_Dia  \
# 0    2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Manhã
# 1200 2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Tarde
# 2400 2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Noite
# 100  2023-04-15      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Manhã
# 1300 2023-04-15      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Tarde
#
#           Hora           Nome da Loja  NinjaInfo  Semana     Dia
# 0     10:39:00  Continente Matosinhos        1.0       1   Sexta
# 1200  14:46:00  Continente Matosinhos        1.0       1   Sexta
# 2400  19:08:00  Continente Matosinhos        1.0       1   Sexta
# 100   10:56:25  Continente Matosinhos        1.0       1  Sábado
# 1300  15:19:35  Continente Matosinhos        1.0       1  Sábado

# %% [markdown]
# #  <span style="color:red"><u> Mergir</u> </span>

# %% [markdown]
# - # `dfFinal`

# %%
dfMeio = pd.merge(dfNinjasLong, dfDelta, how="left", on = ["DATA","STORE", "DESC_ARTIGO"])
dfMeio = dfMeio.drop(columns=["Loja"])


dfFinal=dfMeio.sort_values(by=["STORE","DESC_ARTIGO","DATA"]).copy()

# %% [markdown]
# >Sinal

# %%
# Categorias possíveis
mapping = {1: "Presente com Stock",
           2: "Ausente com Stock",
           3: "Presente sem Stock",
           4: "Ausente sem Stock",
           5: "Presente sem Registo",
           6: "Ausente sem Registo"}

# Definir coluna de sinal
dfFinal["Sinal"] = np.where((dfFinal["STOCK"] > 0) & (dfFinal["NinjaInfo"] == 1), 1,
                     np.where((dfFinal["STOCK"] > 0) & (dfFinal["NinjaInfo"] == 0), 2,
                     np.where((dfFinal["STOCK"] <= 0) & (dfFinal["NinjaInfo"] == 1), 3,
                     np.where((dfFinal["STOCK"] <= 0) & (dfFinal["NinjaInfo"] == 0), 4,
                     np.where((dfFinal["STOCK"].isna()) & (dfFinal["NinjaInfo"] == 1), 5,
                     np.where((dfFinal["STOCK"].isna()) & (dfFinal["NinjaInfo"] == 0), 6,
                     np.nan))))))

# Substituir números pelas expressões escolhidas
dfFinal["Sinal"] = dfFinal["Sinal"].map(mapping)

# %% [markdown]
# # <span style="color:Blue">Outras métricas</span>

# %% [markdown]
# > Reabastecimento

# %%
dfFinal["Restock"] = np.where(dfFinal["STOCK"] > dfFinal["STOCK"].shift(), "Houve reabastecimento",
                                np.where((dfFinal["STOCK"] <= 0) & (dfFinal["STOCK"].shift() > 0), "Houve rotura", 0))

#Fazer um groupby

dfFinal.Restock.value_counts()
# Out:
# 0                        3278
# Houve reabastecimento     320
# Houve rotura                2
# Name: Restock, dtype: int64

# %%
dfFinal["Restock"] = dfFinal.groupby("DESC_ARTIGO").apply(
    lambda group: np.where(
        group["STOCK"] > group["STOCK"].shift(), "Houve reabastecimento",
        np.where((group["STOCK"] <= 0) & (group["STOCK"].shift() > 0), "Houve rotura", 0)
    )
).reset_index(drop=True)

# %%
dfFinal[['DATA', 'STORE', 'DESC_ARTIGO', 'Altura_do_Dia', 'Hora', 'Nome da Loja', 'NinjaInfo', 'Semana', 'Dia', 'Restock']].head()
# Out:
#         DATA  STORE                             DESC_ARTIGO Altura_do_Dia  \
# 0 2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Manhã
# 1 2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Tarde
# 2 2023-04-14      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Noite
# 3 2023-04-15      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Manhã
# 4 2023-04-15      1  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Tarde
#
#        Hora           Nome da Loja  NinjaInfo  Semana     Dia Restock
# 0  10:39:00  Continente Matosinhos        1.0       1   Sexta       0
# 1  14:46:00  Continente Matosinhos        1.0       1   Sexta       0
# 2  19:08:00  Continente Matosinhos        1.0       1   Sexta       0
# 3  10:56:25  Continente Matosinhos        1.0       1  Sábado       0
# 4  15:19:35  Continente Matosinhos        1.0       1  Sábado       0

# %% [markdown]
# - Roturas Reais (Ninjas)

# %%
#1 Quando detectada rotura
dfFinal["Roturas_Linear_dia"] = dfFinal[dfFinal['NinjaInfo'] == 0].groupby(['STORE', 'DATA', 'DESC_ARTIGO'])['NinjaInfo'].transform('count')

#0 Quando não há rotura
dfFinal["Roturas_Linear_dia"] = np.where(dfFinal['NinjaInfo'] == 1, 0, dfFinal['Roturas_Linear_dia'])

# %% [markdown]
# - Roturas consecutivas por dia

# %%
#Detectar em quais é que há consecutivas
dfFinal['Roturas_Consecutivas'] = dfFinal.groupby(['STORE', 'Semana', 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].apply(lambda x: ((x == 0) & (x.shift(1) == 0)).astype(int))


#Há um problema na linha de baixo! só quero que some a soma
#Somar para saber o total
dfFinal['Roturas_Consecutivas'] = dfFinal.groupby(['STORE', 'Semana', 'DESC_ARTIGO'], group_keys=False)['Roturas_Consecutivas'].apply(
    lambda x: x.groupby((x != x.shift()).cumsum()).cumsum() if any(x == 1) else x)

# %%
dfFinal[['DATA', 'DESC_ARTIGO', 'Altura_do_Dia', 'Nome da Loja', 'NinjaInfo', 'Semana', 'Dia', 'Roturas_Consecutivas']][dfFinal["NinjaInfo"]==0].head(40)
# Out:
#            DATA                             DESC_ARTIGO Altura_do_Dia  \
# 424  2023-05-05           CAFÉ BELLISSIMO INTENSO 200GR         Tarde
# 425  2023-05-05           CAFÉ BELLISSIMO INTENSO 200GR         Noite
# 426  2023-05-06           CAFÉ BELLISSIMO INTENSO 200GR         Manhã
# 427  2023-05-06           CAFÉ BELLISSIMO INTENSO 200GR         Tarde
# 428  2023-05-06           CAFÉ BELLISSIMO INTENSO 200GR         Noite
# 429  2023-05-07           CAFÉ BELLISSIMO INTENSO 200GR         Manhã
# 750  2023-05-06  BEBIDA CEREAIS DELTA C/20%CAFE FR 200G         Manhã
# 821  2023-05-05               CAFÉ DELTA Q MYTHIQ 80CAP         Noite
# 1152 2023-04-14               CAFÉ DELTA Q MYTHIQ 80CAP         Manhã
# 1153 2023-04-14               CAFÉ DELTA Q MYTHIQ 80CAP         Tarde
# 1154 2023-04-14               CAFÉ DELTA Q MYTHIQ 80CAP         Noite
# 1160 2023-04-16               CAFÉ DELTA Q MYTHIQ 80CAP         Noite
# 1163 2023-04-21               CAFÉ DELTA Q MYTHIQ 80CAP         Noite
# 1256 2023-05-06              CAFÉ DELTA Q QALIDUS 80CAP         Noite
# 1257 2023-05-07              CAFÉ DELTA Q QALIDUS 80CAP         Manhã
# 1258 2023-05-07              CAFÉ DELTA Q QALIDUS 80CAP         Tarde
# 1504 2023-05-05           CAFÉ BELLISSIMO INTENSO 200GR         Tarde
# 1505 2023-05-05           CAFÉ BELLISSIMO INTENSO 200GR         Noite
# 1506 2023-05-06           CAFÉ BELLISSIMO INTENSO 200GR         Manhã
# 1729 2023-04-14          CAFÉ SOLÚVEL DELTA FRASCO 200G         Tarde
# 1730 2023-04-14          CAFÉ SOLÚVEL DELTA FRASCO 200G         Noite
# 1885 2023-04-22               CAFÉ DELTA Q MYTHIQ 80CAP         Tarde
# 1886 2023-04-22               CAFÉ DELTA Q MYTHIQ 80CAP         Noite
# 1887 2023-04-23               CAFÉ DELTA Q MYTHIQ 80CAP         Manhã
# 1888 2023-04-23               CAFÉ DELTA Q MYTHIQ 80CAP         Tarde
# 1915 2023-04-16              CAFÉ DELTA Q QALIDUS 10CAP         Tarde
# 1916 2023-04-16              CAFÉ DELTA Q QALIDUS 10CAP         Noite
# 1919 2023-04-21              CAFÉ DELTA Q QALIDUS 10CAP         Noite
# 1920 2023-04-22              CAFÉ DELTA Q QALIDUS 10CAP         Manhã
# 1921 2023-04-22              CAFÉ DELTA Q QALIDUS 10CAP         Tarde
# 1922 2023-04-22              CAFÉ DELTA Q QALIDUS 10CAP         Noite
# 1923 2023-04-23              CAFÉ DELTA Q QALIDUS 10CAP         Manhã
# 1924 2023-04-23              CAFÉ DELTA Q QALIDUS 10CAP         Tarde
# 1952 2023-04-16              CAFÉ DELTA Q QALIDUS 80CAP         Noite
# 1953 2023-04-21              CAFÉ DELTA Q QALIDUS 80CAP         Manhã
# 1954 2023-04-21              CAFÉ DELTA Q QALIDUS 80CAP         Tarde
# 1955 2023-04-21              CAFÉ DELTA Q QALIDUS 80CAP         Noite
# 1956 2023-04-22              CAFÉ DELTA Q QALIDUS 80CAP         Manhã
# 1957 2023-04-22              CAFÉ DELTA Q QALIDUS 80CAP         Tarde
# 1958 2023-04-22              CAFÉ DELTA Q QALIDUS 80CAP         Noite
#
#                      Nome da Loja  NinjaInfo  Semana      Dia  \
# 424            Continente Amadora        0.0       4    Sexta
# 425            Continente Amadora        0.0       4    Sexta
# 426            Continente Amadora        0.0       4   Sábado
# 427            Continente Amadora        0.0       4   Sábado
# 428            Continente Amadora        0.0       4   Sábado
# 429            Continente Amadora        0.0       4  Domingo
# 750            Continente Cascais        0.0       4   Sábado
# 821            Continente Cascais        0.0       4    Sexta
# 1152            Continente Leiria        0.0       1    Sexta
# 1153            Continente Leiria        0.0       1    Sexta
# 1154            Continente Leiria        0.0       1    Sexta
# 1160            Continente Leiria        0.0       1  Domingo
# 1163            Continente Leiria        0.0       2    Sexta
# 1256            Continente Leiria        0.0       4   Sábado
# 1257            Continente Leiria        0.0       4  Domingo
# 1258            Continente Leiria        0.0       4  Domingo
# 1504  Continente Coimbra shopping        0.0       4    Sexta
# 1505  Continente Coimbra shopping        0.0       4    Sexta
# 1506  Continente Coimbra shopping        0.0       4   Sábado
# 1729  Continente Coimbra shopping        0.0       1    Sexta
# 1730  Continente Coimbra shopping        0.0       1    Sexta
# 1885       Continente de Portimão        0.0       2   Sábado
# 1886       Continente de Portimão        0.0       2   Sábado
# 1887       Continente de Portimão        0.0       2  Domingo
# 1888       Continente de Portimão        0.0       2  Domingo
# 1915       Continente de Portimão        0.0       1  Domingo
# 1916       Continente de Portimão        0.0       1  Domingo
# 1919       Continente de Portimão        0.0       2    Sexta
# 1920       Continente de Portimão        0.0       2   Sábado
# 1921       Continente de Portimão        0.0       2   Sábado
# 1922       Continente de Portimão        0.0       2   Sábado
# 1923       Continente de Portimão        0.0       2  Domingo
# 1924       Continente de Portimão        0.0       2  Domingo
# 1952       Continente de Portimão        0.0       1  Domingo
# 1953       Continente de Portimão        0.0       2    Sexta
# 1954       Continente de Portimão        0.0       2    Sexta
# 1955       Continente de Portimão        0.0       2    Sexta
# 1956       Continente de Portimão        0.0       2   Sábado
# 1957       Continente de Portimão        0.0       2   Sábado
# 1958       Continente de Portimão        0.0       2   Sábado
#
#       Roturas_Consecutivas
# 424                      0
# 425                      1
# 426                      2
# 427                      3
# 428                      4
# 429                      5
# 750                      0
# 821                      0
# 1152                     0
# 1153                     1
# 1154                     2
# 1160                     0
# 1163                     0
# 1256                     0
# 1257                     1
# 1258                     2
# 1504                     0
# 1505                     1
# 1506                     2
# 1729                     0
# 1730                     1
# 1885                     0
# 1886                     1
# 1887                     2
# 1888                     3
# 1915                     0
# 1916                     1
# 1919                     0
# 1920                     1
# 1921                     2
# 1922                     3
# 1923                     4
# 1924                     5
# 1952                     0
# 1953                     0
# 1954                     1
# 1955                     2
# 1956                     3
# 1957                     4
# 1958                     5

# %% [markdown]
# - Roturas consecutivas entre dias

# %%
#Detectar Roturas consecutivas entre dias do mesmo fim de semana
dfFinal['Roturas_Consecutivas_fds'] = dfFinal.groupby(['STORE', dfFinal['DATA'].dt.isocalendar().week, 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].apply(lambda x: ((x == 0) & (x.shift(1) == 0)).astype(int))
dfFinal['Roturas_Consecutivas_fds'] = dfFinal.groupby(['STORE', dfFinal['DATA'].dt.isocalendar().week, 'DESC_ARTIGO'], group_keys=False)['Roturas_Consecutivas_fds'].transform(lambda x: (x.cumsum() if any(x == 1) else x))
#Eliminar valores repetidos quando não está a haver rotura
dfFinal['Roturas_Consecutivas_fds'] =np.where(dfFinal["Roturas_Linear_dia"] == 0, 0, dfFinal['Roturas_Consecutivas_fds'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3_recent\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3_recent\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3_recent\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Roturas_Linear_dia'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 5
#       3 dfFinal['Roturas_Consecutivas_fds'] = dfFinal.groupby(['STORE', dfFinal['DATA'].dt.isocalendar().week, 'DESC_ARTIGO'], group_keys=False)['Roturas_Consecutivas_fds'].transform(lambda x: (x.cumsum() if any(x == 1) else x))
#       4 #Eliminar valores repetidos quando não está a haver rotura
# ----> 5 dfFinal['Roturas_Consecutivas_fds'] =np.where(dfFinal["Roturas_Linear_dia"] == 0, 0, dfFinal['Roturas_Consecutivas_fds'])
#
# File ~\anaconda3_recent\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3_recent\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Roturas_Linear_dia'

# %% [markdown]
# - Proporção

# %%
dfFinal['Proporção_Consecutivas_dia'] = dfFinal.groupby(['STORE', 'DATA', 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].transform('mean')
dfFinal['Std_Consecutivas_dia'] = dfFinal.groupby(['STORE', 'DATA', 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].transform('std')

dfFinal['Proporção_Consecutivas_fds'] = dfFinal.groupby(['Semana', 'STORE', 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].transform('mean')
dfFinal['Std_Consecutivas_fds'] = dfFinal.groupby(['Semana', 'STORE', 'DESC_ARTIGO'], group_keys=False)['NinjaInfo'].transform('std')

# %%
dfFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3600 entries, 0 to 3599
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATA                         3600 non-null   datetime64[ns]
#  1   STORE                        3600 non-null   int64
#  2   DESC_ARTIGO                  3600 non-null   object
#  3   Altura_do_Dia                3600 non-null   object
#  4   Hora                         3010 non-null   object
#  5   Nome da Loja                 3600 non-null   object
#  6   NinjaInfo                    3010 non-null   float64
#  7   Semana                       3600 non-null   int64
#  8   Dia                          3600 non-null   object
#  9   EAN                          3600 non-null   int64
#  10  INTRANSIT                    3600 non-null   int64
#  11  EXPECTED                     3600 non-null   int64
#  12  PRES_STOCK                   3600 non-null   int64
#  13  STOCK                        3600 non-null   float64
#  14  SELLOUT                      3600 non-null   float64
#  15  Prophet                      3600 non-null   float64
#  16  XGBoost                      3600 non-null   float64
#  17  ROTURA                       3600 non-null   int64
#  18  PRE_ROTURA                   3600 non-null   int64
#  19  Volatilidade_30              3600 non-null   float64
#  20  Volatilidade_60              3600 non-null   float64
#  21  Volatilidade_120             3600 non-null   float64
#  22  Volatilidade_180             3600 non-null   float64
#  23  Percentagem_Roturas_30       3600 non-null   float64
#  24  Percentagem_Roturas_60       3600 non-null   float64
#  25  Percentagem_Roturas_120      3600 non-null   float64
#  26  Percentagem_Roturas_180      3600 non-null   float64
#  27  New_Supply                   3600 non-null   int64
#  28  Percentagem_Supply_30        3600 non-null   float64
#  29  Percentagem_Supply_60        3600 non-null   float64
#  30  Percentagem_Supply_120       3600 non-null   float64
#  31  Percentagem_Supply_180       3600 non-null   float64
#  32  SELLOUT_fds                  3600 non-null   float64
#  33  SELLOUT_semana               0 non-null      float64
#  34  Efeito_Fds_30                3504 non-null   float64
#  35  Efeito_Fds_60                3501 non-null   float64
#  36  Efeito_Fds_120               3537 non-null   float64
#  37  Efeito_Fds_180               3564 non-null   float64
#  38  InterSupply                  615 non-null    float64
#  39  InterSupplyMed_30            3522 non-null   float64
#  40  InterSupplyMed_60            3582 non-null   float64
#  41  InterSupplyMed_120           3600 non-null   float64
#  42  InterSupplyMed_180           3600 non-null   float64
#  43  Tempo_Indisponível           3 non-null      float64
#  44  Tempo_Indisponível_30        216 non-null    float64
#  45  Tempo_Indisponível_60        732 non-null    float64
#  46  Tempo_Indisponível_120       1191 non-null   float64
#  47  Tempo_Indisponível_180       1635 non-null   float64
#  48  Stock_Borderline             3600 non-null   int64
#  49  Tempo_Stock_Borderline_30    3600 non-null   float64
#  50  Tempo_Stock_Borderline_60    3600 non-null   float64
#  51  Tempo_Stock_Borderline_120   3600 non-null   float64
#  52  Tempo_Stock_Borderline_180   3600 non-null   float64
#  53  Linear_Incompleto            3600 non-null   int64
#  54  Tempo_Linear_Incompleto_30   3600 non-null   float64
#  55  Tempo_Linear_Incompleto_60   3600 non-null   float64
#  56  Tempo_Linear_Incompleto_120  3600 non-null   float64
#  57  Tempo_Linear_Incompleto_180  3600 non-null   float64
#  58  Sem_Vendas                   3600 non-null   int64
#  59  Sem_Vendas_30                3600 non-null   float64
#  60  Sem_Vendas_60                3600 non-null   float64
#  61  Sem_Vendas_120               3600 non-null   float64
#  62  Sem_Vendas_180               3600 non-null   float64
#  63  ROTURA_fds                   3600 non-null   float64
#  64  ROTURA_semana                0 non-null      float64
#  65  Vendas_Perdidas_30           3600 non-null   float64
#  66  Vendas_Perdidas_60           3600 non-null   float64
#  67  Vendas_Perdidas_120          3600 non-null   float64
#  68  Vendas_Perdidas_180          3600 non-null   float64
#  69  STK                          3600 non-null   float64
#  70  MSA10                        3600 non-null   float64
#  71  MSA10Dp                      3600 non-null   float64
#  72  MSA20                        3600 non-null   float64
#  73  MSA20Dp                      3600 non-null   float64
#  74  CICLOS                       3600 non-null   float64
#  75  Dias_para_Rotura_Stock       3600 non-null   float64
#  76  Dias_Duração_Linear          3600 non-null   float64
#  77  Adequação                    3600 non-null   object
#  78  Balance                      3600 non-null   float64
#  79  Balance_Optimized            3600 non-null   float64
#  80  Balance_Mediano              3600 non-null   float64
#  81  Balance_Liberal              3600 non-null   float64
#  82  Balance_Conservador          3600 non-null   float64
#  83  Reposição                    3600 non-null   int64
#  84  Sinal                        3010 non-null   object
#  85  Restock                      3600 non-null   object
#  86  Roturas_Linear_dia           3010 non-null   float64
#  87  Roturas_Consecutivas_dia     3600 non-null   int32
#  88  Roturas_Consecutivas_fds     3600 non-null   int32
#  89  Proporção_Consecutivas_dia   3360 non-null   float64
#  90  Std_Consecutivas_dia         3120 non-null   float64
#  91  Proporção_Consecutivas_fds   3600 non-null   float64
#  92  Std_Consecutivas_fds         3420 non-null   float64
# dtypes: datetime64[ns](1), float64(69), int32(2), int64(13), object(8)
# memory usage: 2.6+ MB

# %%
dfFinal.info()
escrever_excel(dfFinal, "Paratestarcerto")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3600 entries, 0 to 3599
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATA                         3600 non-null   datetime64[ns]
#  1   STORE                        3600 non-null   int64
#  2   DESC_ARTIGO                  3600 non-null   object
#  3   Altura_do_Dia                3600 non-null   object
#  4   Hora                         3010 non-null   object
#  5   Nome da Loja                 3600 non-null   object
#  6   NinjaInfo                    3010 non-null   float64
#  7   Semana                       3600 non-null   int64
#  8   Dia                          3600 non-null   object
#  9   EAN                          3600 non-null   int64
#  10  INTRANSIT                    3600 non-null   int64
#  11  EXPECTED                     3600 non-null   int64
#  12  PRES_STOCK                   3600 non-null   int64
#  13  STOCK                        3600 non-null   float64
#  14  SELLOUT                      3600 non-null   float64
#  15  Prophet                      3600 non-null   float64
#  16  XGBoost                      3600 non-null   float64
#  17  ROTURA                       3600 non-null   int64
#  18  PRE_ROTURA                   3600 non-null   int64
#  19  Volatilidade_30              3600 non-null   float64
#  20  Volatilidade_60              3600 non-null   float64
#  21  Volatilidade_120             3600 non-null   float64
#  22  Volatilidade_180             3600 non-null   float64
#  23  Percentagem_Roturas_30       3600 non-null   float64
#  24  Percentagem_Roturas_60       3600 non-null   float64
#  25  Percentagem_Roturas_120      3600 non-null   float64
#  26  Percentagem_Roturas_180      3600 non-null   float64
#  27  New_Supply                   3600 non-null   int64
#  28  Percentagem_Supply_30        3600 non-null   float64
#  29  Percentagem_Supply_60        3600 non-null   float64
#  30  Percentagem_Supply_120       3600 non-null   float64
#  31  Percentagem_Supply_180       3600 non-null   float64
#  32  SELLOUT_fds                  3600 non-null   float64
#  33  SELLOUT_semana               0 non-null      float64
#  34  Efeito_Fds_30                3504 non-null   float64
#  35  Efeito_Fds_60                3501 non-null   float64
#  36  Efeito_Fds_120               3537 non-null   float64
#  37  Efeito_Fds_180               3564 non-null   float64
#  38  InterSupply                  615 non-null    float64
#  39  InterSupplyMed_30            3522 non-null   float64
#  40  InterSupplyMed_60            3582 non-null   float64
#  41  InterSupplyMed_120           3600 non-null   float64
#  42  InterSupplyMed_180           3600 non-null   float64
#  43  Tempo_Indisponível           3 non-null      float64
#  44  Tempo_Indisponível_30        216 non-null    float64
#  45  Tempo_Indisponível_60        732 non-null    float64
#  46  Tempo_Indisponível_120       1191 non-null   float64
#  47  Tempo_Indisponível_180       1635 non-null   float64
#  48  Stock_Borderline             3600 non-null   int64
#  49  Tempo_Stock_Borderline_30    3600 non-null   float64
#  50  Tempo_Stock_Borderline_60    3600 non-null   float64
#  51  Tempo_Stock_Borderline_120   3600 non-null   float64
#  52  Tempo_Stock_Borderline_180   3600 non-null   float64
#  53  Linear_Incompleto            3600 non-null   int64
#  54  Tempo_Linear_Incompleto_30   3600 non-null   float64
#  55  Tempo_Linear_Incompleto_60   3600 non-null   float64
#  56  Tempo_Linear_Incompleto_120  3600 non-null   float64
#  57  Tempo_Linear_Incompleto_180  3600 non-null   float64
#  58  Sem_Vendas                   3600 non-null   int64
#  59  Sem_Vendas_30                3600 non-null   float64
#  60  Sem_Vendas_60                3600 non-null   float64
#  61  Sem_Vendas_120               3600 non-null   float64
#  62  Sem_Vendas_180               3600 non-null   float64
#  63  ROTURA_fds                   3600 non-null   float64
#  64  ROTURA_semana                0 non-null      float64
#  65  Vendas_Perdidas_30           3600 non-null   float64
#  66  Vendas_Perdidas_60           3600 non-null   float64
#  67  Vendas_Perdidas_120          3600 non-null   float64
#  68  Vendas_Perdidas_180          3600 non-null   float64
#  69  STK                          3600 non-null   float64
#  70  MSA10                        3600 non-null   float64
#  71  MSA10Dp                      3600 non-null   float64
#  72  MSA20                        3600 non-null   float64
#  73  MSA20Dp                      3600 non-null   float64
#  74  CICLOS                       3600 non-null   float64
#  75  Dias_para_Rotura_Stock       3600 non-null   float64
#  76  Dias_Duração_Linear          3600 non-null   float64
#  77  Adequação                    3600 non-null   object
#  78  Balance                      3600 non-null   float64
#  79  Balance_Optimized            3600 non-null   float64
#  80  Balance_Mediano              3600 non-null   float64
#  81  Balance_Liberal              3600 non-null   float64
#  82  Balance_Conservador          3600 non-null   float64
#  83  Reposição                    3600 non-null   int64
#  84  Sinal                        3010 non-null   object
#  85  Restock                      3600 non-null   object
#  86  Roturas_Linear_dia           3010 non-null   float64
#  87  Roturas_Consecutivas_dia     3600 non-null   int32
#  88  Roturas_Consecutivas_fds     3600 non-null   int32
#  89  Proporção_Consecutivas_dia   3360 non-null   float64
#  90  Std_Consecutivas_dia         3120 non-null   float64
#  91  Proporção_Consecutivas_fds   3600 non-null   float64
#  92  Std_Consecutivas_fds         3420 non-null   float64
# dtypes: datetime64[ns](1), float64(69), int32(2), int64(13), object(8)
# memory usage: 2.6+ MB

# %% [markdown]
# # Escrever

# %%
escrever_excel(dfFinal, "Long_DataFusion_PilotoCerto")
