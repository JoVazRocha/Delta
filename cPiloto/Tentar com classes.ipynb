# %% [markdown]
# # Com Classes

# %%
import pandas as pd

# %%
path = "D:\\B&N Dados\\Delta\\Piloto\\"
ninjas = "1Ninjas1fds.xlsx"
#delta = 
#sonae = 
resto = 4
coluna = 5

# %%
class Base():
    
    """ This class displays the summary of the tabular data contained in a CSV file """
    
    def __init__(self, path, ninjas, delta, sonae, resto, coluna):
        self.path = path
        self.ninjas = ninjas
        self.delta = delta
        self.sonae = sonae
        self.resto = resto
        self.coluna = coluna
        

    def ficheiros(self):
        dfNinjas = pd.read_excel(self.path + self.ninjas)
        #dfDelta = pd.read_excel(self.path + self.delta)
        #dfSonae = pd.read_excel(self.path + self.sonae)
        return dfNinjas

# %%
final=Base(path, ninjas, 1, 2, resto, coluna)

# %%
final.ficheiros()
# Out:
#                        Nome da Loja  Código da loja  Data de Resposta  \
# 0             Continente Matosinhos               1        2023-04-14
# 1             Continente Matosinhos               1        2023-04-14
# 2             Continente Matosinhos               1        2023-04-14
# 3             Continente Matosinhos               1        2023-04-15
# 4             Continente Matosinhos               1        2023-04-15
# 5             Continente Matosinhos               1        2023-04-15
# 6             Continente Matosinhos               1        2023-04-16
# 7             Continente Matosinhos               1        2023-04-16
# 8                Continente Amadora               2        2023-04-14
# 9                Continente Amadora               2        2023-04-14
# 10               Continente Amadora               2        2023-04-15
# 11               Continente Cascais               3        2023-04-14
# ...

# %%
oioi.display_summary()
# Out:
# 1Ninjas1fds.xlsx
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 14 columns):
# Nome da Loja                                    70 non-null object
# Código da loja                                  70 non-null int64
#  Data de Resposta                               70 non-null datetime64[ns]
# Hora                                            70 non-null object
# Delta Q Gran Mythiq 80                          70 non-null int64
# Delta Q Gran Qalidus 80                         70 non-null int64
# Delta Q Qalidus tubo 10                         70 non-null int64
# Delta Cafés Lote Chávena Moagem Máquina 250g    70 non-null int64
# Bellissimo Aroma Intenso 200g                   70 non-null int64
# Delta Ritual 220g                               70 non-null int64
# Delta Cafés Solúvel 100g                        70 non-null int64
# Delta Cafés Solúvel 200g                        70 non-null int64
# ...
